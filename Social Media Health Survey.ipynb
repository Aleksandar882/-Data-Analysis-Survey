# %%
import pandas as pd

# %%
data = pd.read_csv('/content/data-project-final.csv')

# %% [markdown]
# # New section

# %%
data.head()
# Out:
#                      Timestamp     Sex       Age        Eco_Status Everyday  \
# 0  2024/01/03 9:36:49 PM GMT+1  Женски  19 до 29          Вработен       Да
# 1  2024/01/03 9:38:22 PM GMT+1   Машки  30 до 49          Вработен       Да
# 2  2024/01/03 9:43:36 PM GMT+1  Женски  19 до 29  Невработено лице       Да
# 3  2024/01/03 9:48:51 PM GMT+1   Машки  19 до 29          Вработен       Да
# 4  2024/01/03 9:52:56 PM GMT+1   Машки       50+          Вработен       Не
#
#     Favorite   Type                                       Type_Content  \
# 0     TikTok  Видеа  Здрава исхрана и нутриционизам;Продукти за здр...
# 1    Youtube  Видеа                                Ништо од наведеното
# 2  Instagram  Видеа             Содржини за физичка активност и фитнес
# 3  Instagram  Слики                                Ништо од наведеното
# 4    Youtube  Видеа  Здрава исхрана и нутриционизам;Одмор и рекреација
#
#   Fowollers_Important Comments_Important Competent  \
# ...

# %%
fig10 = data['Fowollers_Important'].hist()
fig10=px.bar(data, x='Fowollers_Important', labels={
                     "Fowollers_Important": "Важен е број на следбеници",
                     "count":"Број на испитаници"
                 }                )
fig10.update_layout(
    font_size=17
)
fig10.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data['Positive_Res'].hist()
# Out:
# <Axes: >

# %%
data
# Out:
#                        Timestamp     Sex       Age        Eco_Status Everyday  \
# 0    2024/01/03 9:36:49 PM GMT+1  Женски  19 до 29          Вработен       Да
# 1    2024/01/03 9:38:22 PM GMT+1   Машки  30 до 49          Вработен       Да
# 2    2024/01/03 9:43:36 PM GMT+1  Женски  19 до 29  Невработено лице       Да
# 3    2024/01/03 9:48:51 PM GMT+1   Машки  19 до 29          Вработен       Да
# 4    2024/01/03 9:52:56 PM GMT+1   Машки       50+          Вработен       Не
# ..                           ...     ...       ...               ...      ...
# 59   2024/01/05 9:15:34 AM GMT+1  Женски       50+          Вработен       Да
# 60  2024/01/05 10:53:58 AM GMT+1   Машки  19 до 29  Невработено лице       Да
# 61   2024/01/05 5:20:45 PM GMT+1  Женски  19 до 29  Невработено лице       Да
# 62   2024/01/05 5:20:50 PM GMT+1   Машки  19 до 29          Вработен       Да
# 63   2024/01/05 8:38:26 PM GMT+1   Машки  19 до 29          Вработен       Да
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
data['Age'].hist()
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, '19 до 29'),
#   Text(1, 0, '30 до 49'),
#   Text(2, 0, '50+'),
#   Text(3, 0, '13 до 18')])

# %%
data['Age'].hist(bins = 4)
# Out:
# <Axes: >

# %%
import plotly.express as px

# %%
fig=px.bar(data, x='Age', color='Favorite',labels={
                     "Favorite": "Омилена социјална мрежа",
                     "Age": "Возрастна Група",
                     "count":"Број"
                 },
                title="Омилена социјална мрежа според возраст")

# %%
fig8=px.bar(data, x='Ever_Used', color='Positive_Res', labels={
                     "Positive_Res": "Има позитивно <br> искуство",
                     "Ever_Used": "Применил/а совети од промотери",
                     "count":"Број на испитаници"
                 },
                title="Позитивни искуства од применети совети за здрави навики")

fig8.update_layout(
    font_size=17
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # New section

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2=px.bar(data, x='Favorite', facet_col='Age', labels={
                     "Favorite": "",
                     "Age": "Возрастна Група",
                     "count":"Број"
                 },
                title="Омилена социјална мрежа според возраст")

# %%
fig2.update_layout(
    font_size=17
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.histogram(data, x="Favorite",labels={
                     "Favorite": "Омилена социјална мрежа",
                     "count":"Број"
                 },
                title="Омилена социјална мрежа")

# %%
fig3.update_layout(yaxis_title="Број")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig4 = px.histogram(data, x="Age",labels={
                     "Аge": "Возраст",
                     "count":"Број"
                 },
                title="Возраст")

# %%
fig4.update_layout(yaxis_title="Број")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig5=px.bar(data, x='Favorite', color='Sex',labels={
                     "Favorite": "Омилена социјална мрежа",
                     "Sex": "Пол",
                     "count":"Број"
                 },
                color_discrete_sequence=["pink", "lightblue"],
                title="Омилена социјална мрежа според пол")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7057c10747f7> in <cell line: 1>()
# ----> 1 fig5=px.bar(data, x='Favorite', color='Sex',labels={
#       2                      "Favorite": "Омилена социјална мрежа",
#       3                      "Sex": "Пол",
#       4                      "count":"Број"
#       5                  },
#
# NameError: name 'px' is not defined

# %%
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter_3d(data, x='Age', y='Favorite', z='Sex')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
